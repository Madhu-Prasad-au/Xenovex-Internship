# %%
# !pip install -U transformers accelerate bitsandbytes
# Out:
# ^C

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

model_id = "tiiuae/falcon-7b-instruct"

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_id)

# Load model in 4-bit
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    device_map="auto",
    trust_remote_code=True,
    load_in_4bit=True  # <- critical for Colab T4
)

# Create generation pipeline
generator = pipeline("text-generation", model=model, tokenizer=tokenizer, device_map="auto")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
#       3 model_id = "tiiuae/falcon-7b-instruct"
#       5 # Load tokenizer
#
# File ~\anaconda3\envs\deep-fake\lib\site-packages\transformers\__init__.py:950
#     946 import sys
#     948 _import_structure = {k: set(v) for k, v in _import_structure.items()}
# --> 950 import_structure = define_import_structure(Path(__file__).parent / "models", prefix="models")
#     951 import_structure[frozenset({})].update(_import_structure)
#     953 sys.modules[__name__] = _LazyModule(
#     954     __name__,
#     955     globals()["__file__"],
#    (...)
#     958     extra_objects={"__version__": __version__},
#     959 )
#
# ...

# %%
prompts = [
    "Tell a story about a lonely robot who finds a friend in space.",
    "Imagine you are a robot. Describe your emotions as you drift alone through the galaxy.",
    "Explain the loneliness of AI in a poetic way using metaphors.",
    "Write a bedtime story about a robot exploring Mars to find love."]

for i, prompt in enumerate(prompts, 1):
    #/print(f"\n=== Prompt {i} ===\n{prompt}\n")
    output = generator(prompt,max_new_tokens=250,temperature=0.9,top_k=50,top_p=0.95,repetition_penalty=1.2,do_sample=True,
        pad_token_id=tokenizer.eos_token_id)
    
    print("Generated Output:\n", output[0]['generated_text'],'\n')
    print("=" * 80)
